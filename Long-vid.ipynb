# %%
from vidstab import VidStab
import matplotlib.pyplot as plt

stabilizer = VidStab()
stabilizer.stabilize(input_path='Vid/Long-vid.mov', output_path='Output/Long-vid.avi')

# %%
stabilizer.plot_trajectory()
plot_trajectory = plt.show()

# %%
stabilizer.plot_transforms()
plot_transform = plt.show()

# %%
import pandas as pd
# Convert transforms to a DataFrame and export to Excel
transforms_df = pd.DataFrame(stabilizer.transforms, columns=['dx', 'dy', 'da'])
transforms_df.to_excel('Output/Long-vid.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 # Convert transforms to a DataFrame and export to Excel
# ----> 3 transforms_df = pd.DataFrame(stabilizer.transforms, columns=['dx', 'dy', 'da'])
#       4 transforms_df.to_excel('Output/Long-vid.xlsx', index=False)
#
# NameError: name 'stabilizer' is not defined
