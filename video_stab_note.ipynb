# %%
from vidstab import VidStab
import matplotlib.pyplot as plt

stabilizer = VidStab()
stabilizer.stabilize(input_path='Vid/test1.mov', output_path='Output/test1_stab.avi')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import matplotlib.pyplot as plt
#       4 stabilizer = VidStab()
# ----> 5 stabilizer.stabilize(input_path='input_video.mov', output_path='stable_video.avi')
#
# File c:\Users\Aki-laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\vidstab\VidStab.py:561, in VidStab.stabilize(self, input_path, output_path, smoothing_window, max_frames, border_type, border_size, layer_func, playback, use_stored_transforms, show_progress, output_fourcc, output_fps)
#     558     self.auto_border_flag = True
#     560 if not os.path.exists(input_path) and not isinstance(input_path, int):
# --> 561     raise FileNotFoundError(f'{input_path} does not exist')
#     563 self.frame_queue.set_frame_source(cv2.VideoCapture(input_path))
#     565 # wait for camera to start up
#
# FileNotFoundError: input_video.mov does not exist

# %%
stabilizer.plot_trajectory()
plot_trajectory = plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       2 plot_trajectory = plt.show()
#       3 with open("trajectory_data.txt", "w") as txt_file:
# ----> 4     for frame in stabilizer.stabilize(input_path="Vid/test1.mov", output_path="Output/test1_stab.avi"):
#       5         txt_file.write(f"{frame}\n")
#
# File c:\Users\Aki-laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\vidstab\VidStab.py:595, in VidStab.stabilize(self, input_path, output_path, smoothing_window, max_frames, border_type, border_size, layer_func, playback, use_stored_transforms, show_progress, output_fourcc, output_fps)
#     592     self.extreme_frame_corners = auto_border_utils.extreme_corners(frame_1.image, self.transforms)
#     593     border_size = auto_border_utils.min_auto_border_size(self.extreme_frame_corners)
# --> 595 self._apply_transforms(output_path, max_frames, use_stored_transforms=use_stored_transforms,
#     596                        border_type=border_type, border_size=border_size,
#     597                        layer_func=layer_func, playback=playback,
#     598                        output_fourcc=output_fourcc, progress_bar=bar, output_fps=output_fps)
#
# File c:\Users\Aki-laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\vidstab\VidStab.py:275, in VidStab._apply_transforms(self, output_path, max_frames, use_stored_transforms, output_fourcc, border_type, border_size, layer_func, playback, progress_bar, output_fps)
#     272 if not use_stored_transforms:
#     273     self._gen_next_raw_transform()
# --> 275 transformed = self._apply_next_transform(i, frame_i, use_stored_transforms=use_stored_transforms)
#     277 if transformed is None:
#     278     warnings.warn('Video is longer than available transformations; halting process.')
#
# File c:\Users\Aki-laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\vidstab\VidStab.py:402, in VidStab._apply_next_transform(self, i, frame_i, use_stored_transforms)
#     399 except IndexError:
#     400     return None
# --> 402 transformed = vidstab_utils.transform_frame(frame_i,
#     403                                             transform_i,
#     404                                             self.border_options['border_size'],
#     405                                             self.border_options['border_type'])
#     407 transformed, self.layer_options = vidstab_utils.post_process_transformed_frame(transformed,
#     408                                                                                self.border_options,
#     409                                                                                self.layer_options)
#     411 transformed = transformed.cvt_color(frame_i.color_format)
#
# File c:\Users\Aki-laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\vidstab\vidstab_utils.py:112, in transform_frame(frame, transform, border_size, border_type)
#     109     raise ValueError('Invalid border type')
#     111 transform = build_transformation_matrix(transform)
# --> 112 bordered_frame_image, border_mode = border_frame(frame, border_size, border_type)
#     114 h, w = bordered_frame_image.shape[:2]
#     115 transformed_frame_image = cv2.warpAffine(bordered_frame_image, transform, (w, h), borderMode=border_mode)
#
# File c:\Users\Aki-laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\vidstab\vidstab_utils.py:40, in border_frame(frame, border_size, border_type)
#      35 border_modes = {'black': cv2.BORDER_CONSTANT,
#      36                 'reflect': cv2.BORDER_REFLECT,
#      37                 'replicate': cv2.BORDER_REPLICATE}
#      38 border_mode = border_modes[border_type]
# ---> 40 bordered_frame_image = cv2.copyMakeBorder(frame.image,
#      41                                           top=border_size,
#      42                                           bottom=border_size,
#      43                                           left=border_size,
#      44                                           right=border_size,
#      45                                           borderType=border_mode,
#      46                                           value=[0, 0, 0])
#      48 bordered_frame = Frame(bordered_frame_image, color_format=frame.color_format)
#      50 alpha_bordered_frame = bordered_frame.bgra_image
#
# KeyboardInterrupt:

# %%
stabilizer.plot_transforms()
plot_transform = plt.show()
plt.savefig("plot_transform.png", format="png")
